# %% [markdown]
# ## Unzip, read sound files, convert to image, store in folder

# %%
# Run once to unpack
# !unzip ./data/archive.zip -d ./data/
# Out:
# Archive:  ./data/archive.zip
#   inflating: ./data/cats_dogs/cat_1.wav
#   inflating: ./data/cats_dogs/cat_10.wav
#   inflating: ./data/cats_dogs/cat_100.wav
#   inflating: ./data/cats_dogs/cat_101.wav
#   inflating: ./data/cats_dogs/cat_102.wav
#   inflating: ./data/cats_dogs/cat_103.wav
#   inflating: ./data/cats_dogs/cat_105.wav
#   inflating: ./data/cats_dogs/cat_106.wav
#   inflating: ./data/cats_dogs/cat_107.wav
#   inflating: ./data/cats_dogs/cat_108.wav
#   inflating: ./data/cats_dogs/cat_109.wav
#   inflating: ./data/cats_dogs/cat_11.wav
#   inflating: ./data/cats_dogs/cat_110.wav
#   inflating: ./data/cats_dogs/cat_112.wav
#   inflating: ./data/cats_dogs/cat_113.wav
#   inflating: ./data/cats_dogs/cat_114.wav
#   inflating: ./data/cats_dogs/cat_115.wav
#   inflating: ./data/cats_dogs/cat_116.wav
#   inflating: ./data/cats_dogs/cat_117.wav
#   inflating: ./data/cats_dogs/cat_118.wav
#   inflating: ./data/cats_dogs/cat_119.wav
#   inflating: ./data/cats_dogs/cat_12.wav
#   inflating: ./data/cats_dogs/cat_120.wav
#   inflating: ./data/cats_dogs/cat_121.wav
#   inflating: ./data/cats_dogs/cat_122.wav
#   inflating: ./data/cats_dogs/cat_123.wav
#   inflating: ./data/cats_dogs/cat_124.wav
#   inflating: ./data/cats_dogs/cat_125.wav
#   inflating: ./data/cats_dogs/cat_126.wav
#   inflating: ./data/cats_dogs/cat_127.wav
#   inflating: ./data/cats_dogs/cat_128.wav
#   inflating: ./data/cats_dogs/cat_129.wav
#   inflating: ./data/cats_dogs/cat_13.wav
#   inflating: ./data/cats_dogs/cat_130.wav
#   inflating: ./data/cats_dogs/cat_131.wav
#   inflating: ./data/cats_dogs/cat_132.wav
#   inflating: ./data/cats_dogs/cat_133.wav
#   inflating: ./data/cats_dogs/cat_134.wav
#   inflating: ./data/cats_dogs/cat_135.wav
#   inflating: ./data/cats_dogs/cat_136.wav
#   inflating: ./data/cats_dogs/cat_137.wav
#   inflating: ./data/cats_dogs/cat_138.wav
#   inflating: ./data/cats_dogs/cat_139.wav
#   inflating: ./data/cats_dogs/cat_14.wav
#   inflating: ./data/cats_dogs/cat_140.wav
#   inflating: ./data/cats_dogs/cat_141.wav
#   inflating: ./data/cats_dogs/cat_142.wav
#   inflating: ./data/cats_dogs/cat_143.wav
#   inflating: ./data/cats_dogs/cat_144.wav
#   inflating: ./data/cats_dogs/cat_146.wav
#   inflating: ./data/cats_dogs/cat_147.wav
#   inflating: ./data/cats_dogs/cat_148.wav
#   inflating: ./data/cats_dogs/cat_149.wav
#   inflating: ./data/cats_dogs/cat_15.wav
#   inflating: ./data/cats_dogs/cat_150.wav
#   inflating: ./data/cats_dogs/cat_151.wav
#   inflating: ./data/cats_dogs/cat_152.wav
#   inflating: ./data/cats_dogs/test/test/dog_barking_73.wav
#   inflating: ./data/cats_dogs/test/test/dog_barking_78.wav
#   inflating: ./data/cats_dogs/test/test/dog_barking_8.wav
#   inflating: ./data/cats_dogs/test/test/dog_barking_82.wav
#   inflating: ./data/cats_dogs/test/test/dog_barking_89.wav
#   inflating: ./data/cats_dogs/test/test/dog_barking_9.wav
#   inflating: ./data/cats_dogs/test/test/dog_barking_90.wav
#   inflating: ./data/cats_dogs/test/test/dog_barking_91.wav
#   inflating: ./data/cats_dogs/test/test/dog_barking_99.wav
#   inflating: ./data/cats_dogs/train/cat/cat_1.wav
#   inflating: ./data/cats_dogs/train/cat/cat_10.wav
#   inflating: ./data/cats_dogs/train/cat/cat_100.wav
#   inflating: ./data/cats_dogs/train/cat/cat_101.wav
#   inflating: ./data/cats_dogs/train/cat/cat_102.wav
#   inflating: ./data/cats_dogs/train/cat/cat_103.wav
#   inflating: ./data/cats_dogs/train/cat/cat_105.wav
#   inflating: ./data/cats_dogs/train/cat/cat_106.wav
#   inflating: ./data/cats_dogs/train/cat/cat_107.wav
#   inflating: ./data/cats_dogs/train/cat/cat_108.wav
#   inflating: ./data/cats_dogs/train/cat/cat_109.wav
#   inflating: ./data/cats_dogs/train/cat/cat_11.wav
#   inflating: ./data/cats_dogs/train/cat/cat_113.wav
#   inflating: ./data/cats_dogs/train/cat/cat_114.wav
#   inflating: ./data/cats_dogs/train/cat/cat_116.wav
#   inflating: ./data/cats_dogs/train/cat/cat_117.wav
#   inflating: ./data/cats_dogs/train/cat/cat_118.wav
#   inflating: ./data/cats_dogs/train/cat/cat_119.wav
#   inflating: ./data/cats_dogs/train/cat/cat_12.wav
#   inflating: ./data/cats_dogs/train/cat/cat_120.wav
#   inflating: ./data/cats_dogs/train/cat/cat_121.wav
#   inflating: ./data/cats_dogs/train/cat/cat_122.wav
#   inflating: ./data/cats_dogs/train/cat/cat_123.wav
#   inflating: ./data/cats_dogs/train/cat/cat_124.wav
#   inflating: ./data/cats_dogs/train/cat/cat_125.wav
#   inflating: ./data/cats_dogs/train/cat/cat_127.wav
#   inflating: ./data/cats_dogs/train/cat/cat_128.wav
#   inflating: ./data/cats_dogs/train/cat/cat_13.wav
#   inflating: ./data/cats_dogs/train/cat/cat_131.wav
#   inflating: ./data/cats_dogs/train/cat/cat_132.wav
#   inflating: ./data/cats_dogs/train/cat/cat_134.wav
#   inflating: ./data/cats_dogs/train/cat/cat_136.wav
#   inflating: ./data/cats_dogs/train/cat/cat_138.wav
#   inflating: ./data/cats_dogs/train/cat/cat_139.wav
#   inflating: ./data/cats_dogs/train/cat/cat_140.wav
#   inflating: ./data/cats_dogs/train/cat/cat_141.wav
#   inflating: ./data/cats_dogs/train/cat/cat_142.wav
#   inflating: ./data/cats_dogs/train/cat/cat_146.wav
#   inflating: ./data/cats_dogs/train/cat/cat_147.wav
#   inflating: ./data/cats_dogs/train/cat/cat_149.wav
#   inflating: ./data/cats_dogs/train/cat/cat_15.wav
#   inflating: ./data/cats_dogs/train/cat/cat_150.wav
#   inflating: ./data/cats_dogs/train/cat/cat_151.wav
#   inflating: ./data/cats_dogs/train/cat/cat_153.wav
#   inflating: ./data/cats_dogs/train/cat/cat_154.wav
#   inflating: ./data/cats_dogs/train/cat/cat_155.wav
#   inflating: ./data/cats_dogs/train/cat/cat_156.wav
#   inflating: ./data/cats_dogs/train/cat/cat_157.wav
#   inflating: ./data/cats_dogs/train/cat/cat_159.wav
#   inflating: ./data/cats_dogs/train/cat/cat_16.wav
#   inflating: ./data/cats_dogs/train/cat/cat_160.wav
#   inflating: ./data/cats_dogs/train/cat/cat_161.wav
#   inflating: ./data/cats_dogs/train/cat/cat_162.wav
#   inflating: ./data/cats_dogs/train/cat/cat_163.wav
#   inflating: ./data/cats_dogs/train/cat/cat_164.wav
#   inflating: ./data/cats_dogs/train/cat/cat_165.wav
#   inflating: ./data/cats_dogs/train/cat/cat_166.wav
#   inflating: ./data/cats_dogs/train/cat/cat_167.wav
#   inflating: ./data/cats_dogs/train/cat/cat_18.wav
#   inflating: ./data/cats_dogs/train/cat/cat_19.wav
#   inflating: ./data/cats_dogs/train/cat/cat_2.wav
#   inflating: ./data/cats_dogs/train/cat/cat_21.wav
#   inflating: ./data/cats_dogs/train/cat/cat_22.wav
#   inflating: ./data/cats_dogs/train/cat/cat_23.wav
#   inflating: ./data/cats_dogs/train/cat/cat_25.wav
#   inflating: ./data/cats_dogs/train/cat/cat_26.wav
#   inflating: ./data/cats_dogs/train/cat/cat_27.wav
#   inflating: ./data/cats_dogs/train/cat/cat_30.wav
#   inflating: ./data/cats_dogs/train/cat/cat_31.wav
#   inflating: ./data/cats_dogs/train/cat/cat_32.wav
#   inflating: ./data/cats_dogs/train/cat/cat_33.wav
#   inflating: ./data/cats_dogs/train/cat/cat_34.wav
#   inflating: ./data/cats_dogs/train/cat/cat_35.wav
#   inflating: ./data/cats_dogs/train/cat/cat_37.wav
#   inflating: ./data/cats_dogs/train/cat/cat_38.wav
#   inflating: ./data/cats_dogs/train/cat/cat_39.wav
#   inflating: ./data/cats_dogs/train/cat/cat_4.wav
#   inflating: ./data/cats_dogs/train/cat/cat_40.wav
#   inflating: ./data/cats_dogs/train/cat/cat_41.wav
#   inflating: ./data/cats_dogs/train/cat/cat_43.wav
#   inflating: ./data/cats_dogs/train/cat/cat_44.wav
#   inflating: ./data/cats_dogs/train/cat/cat_45.wav
#   inflating: ./data/cats_dogs/train/cat/cat_46.wav
#   inflating: ./data/cats_dogs/train/cat/cat_47.wav
#   inflating: ./data/cats_dogs/train/cat/cat_48.wav
#   inflating: ./data/cats_dogs/train/cat/cat_49.wav
#   inflating: ./data/cats_dogs/train/cat/cat_5.wav
#   inflating: ./data/cats_dogs/train/cat/cat_50.wav
#   inflating: ./data/cats_dogs/train/cat/cat_51.wav
#   inflating: ./data/cats_dogs/train/cat/cat_52.wav
#   inflating: ./data/cats_dogs/train/cat/cat_53.wav
#   inflating: ./data/cats_dogs/train/cat/cat_54.wav
#   inflating: ./data/cats_dogs/train/cat/cat_6.wav
#   inflating: ./data/cats_dogs/train/cat/cat_60.wav
#   inflating: ./data/cats_dogs/train/cat/cat_62.wav
#   inflating: ./data/cats_dogs/train/cat/cat_63.wav
#   inflating: ./data/cats_dogs/train/cat/cat_64.wav
#   inflating: ./data/cats_dogs/train/cat/cat_65.wav
#   inflating: ./data/cats_dogs/train/cat/cat_68.wav
#   inflating: ./data/cats_dogs/train/cat/cat_69.wav
#   inflating: ./data/cats_dogs/train/cat/cat_7.wav
#   inflating: ./data/cats_dogs/train/cat/cat_70.wav
#   inflating: ./data/cats_dogs/train/cat/cat_71.wav
#   inflating: ./data/cats_dogs/train/cat/cat_72.wav
#   inflating: ./data/cats_dogs/train/cat/cat_73.wav
#   inflating: ./data/cats_dogs/train/cat/cat_74.wav
#   inflating: ./data/cats_dogs/train/cat/cat_77.wav
#   inflating: ./data/cats_dogs/train/cat/cat_78.wav
#   inflating: ./data/cats_dogs/train/cat/cat_8.wav
#   inflating: ./data/cats_dogs/train/cat/cat_80.wav
#   inflating: ./data/cats_dogs/train/cat/cat_81.wav
#   inflating: ./data/cats_dogs/train/cat/cat_83.wav
#   inflating: ./data/cats_dogs/train/cat/cat_84.wav
#   inflating: ./data/cats_dogs/train/cat/cat_87.wav
#   inflating: ./data/cats_dogs/train/cat/cat_89.wav
#   inflating: ./data/cats_dogs/train/cat/cat_9.wav
#   inflating: ./data/cats_dogs/train/cat/cat_91.wav
#   inflating: ./data/cats_dogs/train/cat/cat_92.wav
#   inflating: ./data/cats_dogs/train/cat/cat_93.wav
#   inflating: ./data/cats_dogs/train/cat/cat_94.wav
#   inflating: ./data/cats_dogs/train/cat/cat_95.wav
#   inflating: ./data/cats_dogs/train/cat/cat_96.wav
#   inflating: ./data/cats_dogs/train/cat/cat_97.wav
#   inflating: ./data/cats_dogs/train/cat/cat_98.wav
#   inflating: ./data/cats_dogs/train/cat/cat_99.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_0.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_1.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_10.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_100.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_101.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_102.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_103.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_104.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_105.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_106.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_107.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_108.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_109.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_11.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_110.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_111.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_13.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_14.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_16.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_17.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_18.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_2.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_20.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_21.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_22.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_23.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_25.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_26.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_27.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_28.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_29.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_30.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_31.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_32.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_33.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_35.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_36.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_37.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_38.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_39.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_4.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_40.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_41.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_42.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_47.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_5.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_50.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_51.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_52.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_53.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_55.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_56.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_57.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_58.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_6.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_60.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_61.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_63.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_65.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_67.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_68.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_69.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_70.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_71.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_72.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_74.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_75.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_76.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_77.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_79.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_80.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_81.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_83.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_84.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_85.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_86.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_87.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_88.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_92.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_93.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_94.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_95.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_96.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_97.wav
#   inflating: ./data/cats_dogs/train/dog/dog_barking_98.wav
#   inflating: ./data/train_test_split.csv
#   inflating: ./data/utils.py

# %%
# !pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.10.0.post2-py3-none-any.whl (253 kB)
#      |████████████████████████████████| 253 kB 1.2 MB/s
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.8/site-packages (from librosa) (5.1.0)
# Collecting soxr>=0.3.2
#   Downloading soxr-0.3.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 1.2 MB/s
# Requirement already satisfied: scipy>=1.2.0 in /opt/conda/lib/python3.8/site-packages (from librosa) (1.8.1)
# Requirement already satisfied: numba>=0.51.0 in /opt/conda/lib/python3.8/site-packages (from librosa) (0.55.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /opt/conda/lib/python3.8/site-packages (from librosa) (1.21.5)
# Collecting typing-extensions>=4.1.1
#   Downloading typing_extensions-4.6.2-py3-none-any.whl (31 kB)
# Requirement already satisfied: pooch<1.7,>=1.0 in /opt/conda/lib/python3.8/site-packages (from librosa) (1.5.2)
# Collecting soundfile>=0.12.1
#   Downloading soundfile-0.12.1-py2.py3-none-manylinux_2_31_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 113.5 MB/s
# Requirement already satisfied: msgpack>=1.0 in /opt/conda/lib/python3.8/site-packages (from librosa) (1.0.3)
# Collecting lazy-loader>=0.1
#   Downloading lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: joblib>=0.14 in /opt/conda/lib/python3.8/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.8/site-packages (from librosa) (0.24.1)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      |████████████████████████████████| 377 kB 1.2 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /opt/conda/lib/python3.8/site-packages (from numba>=0.51.0->librosa) (0.38.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from numba>=0.51.0->librosa) (59.8.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.8/site-packages (from pooch<1.7,>=1.0->librosa) (2.25.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.8/site-packages (from pooch<1.7,>=1.0->librosa) (21.3)
# Requirement already satisfied: appdirs in /opt/conda/lib/python3.8/site-packages (from pooch<1.7,>=1.0->librosa) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from scikit-learn>=0.20.0->librosa) (3.0.0)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.8/site-packages (from soundfile>=0.12.1->librosa) (1.15.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.8/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging->pooch<1.7,>=1.0->librosa) (3.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests->pooch<1.7,>=1.0->librosa) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests->pooch<1.7,>=1.0->librosa) (1.26.7)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests->pooch<1.7,>=1.0->librosa) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests->pooch<1.7,>=1.0->librosa) (4.0.0)
# Building wheels for collected packages: audioread
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23706 sha256=c4b6c9df095f773a08cf104c06d427bf2f6c877f5fc30b2fcf5211bb46f1bd30
#   Stored in directory: /home/jovyan/.cache/pip/wheels/0a/ed/be/49df2538fca496690a024a4374455584d65c2afd6fc3d6e9c7
# Successfully built audioread
# Installing collected packages: typing-extensions, soxr, soundfile, lazy-loader, audioread, librosa
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.0.0
#     Uninstalling typing-extensions-4.0.0:
#       Successfully uninstalled typing-extensions-4.0.0
# Successfully installed audioread-3.0.0 lazy-loader-0.2 librosa-0.10.0.post2 soundfile-0.12.1 soxr-0.3.5 typing-extensions-4.6.2

# %%
# Import Libraries
import os

import librosa
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.image import imread
import matplotlib.image as mpimg

import torch
from PIL import Image
import torchvision.transforms as transforms

# %%
df = pd.read_csv('./data/train_test_split.csv')

# %%
df
# Out:
#      Unnamed: 0     test_cat            test_dog    train_cat  \
# 0             0   cat_22.wav  dog_barking_97.wav   cat_99.wav
# 1             1  cat_116.wav   dog_barking_0.wav   cat_54.wav
# 2             2  cat_155.wav  dog_barking_93.wav   cat_34.wav
# 3             3   cat_58.wav  dog_barking_10.wav  cat_132.wav
# 4             4   cat_77.wav  dog_barking_26.wav  cat_124.wav
# ..          ...          ...                 ...          ...
# 110         110          NaN                 NaN   cat_15.wav
# 111         111          NaN                 NaN   cat_88.wav
# 112         112          NaN                 NaN   cat_73.wav
# 113         113          NaN                 NaN   cat_32.wav
# 114         114          NaN                 NaN  cat_113.wav
#
#               train_dog
# 0    dog_barking_33.wav
# 1    dog_barking_86.wav
# 2    dog_barking_45.wav
# 3    dog_barking_76.wav
# 4     dog_barking_4.wav
# ..                  ...
# 110                 NaN
# 111                 NaN
# 112                 NaN
# 113                 NaN
# 114                 NaN
#
# [115 rows x 5 columns]

# %%
#Make new folder to relocate image data
# !mkdir -p img_dataset/train/{cat,dog}
# !mkdir -p img_dataset/test/{cat,dog}

# %%
def create_spectogram(audio_file_name,source_path,save_path): 
    x, sr = librosa.load(source_path+audio_file_name)
    X = librosa.stft(x)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(14, 5))
    librosa.display.specshow(Xdb, sr=sr, y_axis='hz')
    plt.ylabel('')
    plt.axis('off')
    file_name = audio_file_name.replace('.wav','')
    plt.savefig(save_path+file_name+'.jpg', bbox_inches='tight', pad_inches=0)
    plt.close() # Comment if you want to see the image

# %% [markdown]
# ## Image Process one example

# %%
# Convert wav to image

# source sound file, file directory of sound file, destination for image

create_spectogram('cat_1.wav','./data/cats_dogs/train/cat/','./img_dataset/train/cat/')

# %%
# Read a PIL image
image = Image.open('./img_dataset/train/cat/cat_1.jpg')

# %%
# Create the spectogram images:
transform = transforms.Compose([
    transforms.PILToTensor(),
    transforms.Resize(size = (256,256))
])
  
# transform = transforms.PILToTensor()
# Convert the PIL image to Torch tensor
img_tensor = transform(image)
  
# print the converted Torch tensor
print(img_tensor)
# Out:
# tensor([[[ 59,  59,  59,  ...,  59,  59,  59],
#          [ 59,  59,  59,  ...,  59,  59,  59],
#          [ 59,  59,  59,  ...,  59,  59,  59],
#          ...,
#          [191, 214, 216,  ..., 210, 206, 187],
#          [187, 205, 213,  ..., 179, 197, 206],
#          [174, 164, 149,  ..., 184, 164, 190]],
#
#         [[ 76,  76,  76,  ...,  76,  76,  76],
#          [ 76,  76,  76,  ...,  76,  76,  76],
#          [ 76,  76,  76,  ...,  76,  76,  76],
#          ...,
#          [210, 214, 218,  ..., 215, 201, 187],
#          [217, 217, 223,  ..., 192, 200, 213],
#          [212, 181, 162,  ..., 201, 169, 199]],
#
#         [[192, 192, 192,  ..., 192, 192, 192],
#          [192, 192, 192,  ..., 192, 192, 192],
#          [192, 192, 192,  ..., 192, 192, 192],
#          ...,
#          [241, 228, 229,  ..., 241, 225, 209],
#          [241, 226, 237,  ..., 219, 219, 218],
#          [250, 210, 204,  ..., 252, 211, 216]]], dtype=torch.uint8)

# %% [markdown]
# ## Bulk Process Wav to Images for Cat/Dogs and Train/Test

# %%
CAT_TRAIN = './data/cats_dogs/train/cat/' 
for sound in os.listdir(CAT_TRAIN): 
    create_spectogram(sound,CAT_TRAIN,'./img_dataset/train/cat/')
    
DOG_TRAIN = './data/cats_dogs/train/dog/' 
for sound in os.listdir(DOG_TRAIN): 
    create_spectogram(sound,DOG_TRAIN,'./img_dataset/train/dog/')
    
DOG_TEST = './data/cats_dogs/test/test/' 
for sound in os.listdir(DOG_TEST): 
    create_spectogram(sound,DOG_TEST,'./img_dataset/test/dog/')
    
    
CAT_TEST = './data/cats_dogs/test/cats/' 
for sound in os.listdir(CAT_TEST): 
    create_spectogram(sound,CAT_TEST,'./img_dataset/test/cat/')

# %%
Inferences = './data/cats_dogs/inferences/' 
for sound in os.listdir(Inferences): 
    create_spectogram(sound,Inferences,'./img_dataset/inferences/')
# Out:
# Note: Illegal Audio-MPEG-Header 0x4c495354 at offset 38626.
# Note: Trying to resync...
# Note: Hit end of (available) data during resync.

# %%
# Create Metadata for Tensor.Dataset

image_names_ls = []
file_location = []

for i in ['test','train']:
    file_location_subset = []
    for j in ['cat','dog']:
        image_names_ls.append([img for img in os.listdir(f'./img_dataset/{i}/{j}/')])
        file_location.append([f'./img_dataset/{i}/{j}/{img}' for img in os.listdir(f'./img_dataset/{i}/{j}/')])

# %%
test_set = pd.DataFrame({'image_name': image_names_ls[0] + image_names_ls[1], 'image_location': file_location[0] + file_location[1], 'target':len(file_location[0])*['cat']+len(file_location[1])*['dog']} )
train_set = pd.DataFrame({'image_name': image_names_ls[2] + image_names_ls[3], 'image_location': file_location[2] + file_location[3], 'target':len(file_location[2])*['cat']+len(file_location[3])*['dog']})

# %%
test_set.head()
# Out:
#     image_name                      image_location
# 0   cat_28.jpg   ./img_dataset/test/cat/cat_28.jpg
# 1   cat_82.jpg   ./img_dataset/test/cat/cat_82.jpg
# 2   cat_55.jpg   ./img_dataset/test/cat/cat_55.jpg
# 3  cat_110.jpg  ./img_dataset/test/cat/cat_110.jpg
# 4   cat_20.jpg   ./img_dataset/test/cat/cat_20.jpg

# %%
test_set.to_csv('./img_dataset/test/test.csv')
train_set.to_csv('./img_dataset/train/train.csv')

# %% [markdown]
# # Research/References
# 1. Data Source: https://www.kaggle.com/datasets/mmoreaux/audio-cats-and-dogs?select=cats_dogs
# 2. Samples
#     - https://www.kaggle.com/code/thanht02/audio-classification-cnn-864d1f
#     - https://www.kaggle.com/code/kanncaa1/pytorch-tutorial-for-deep-learning-lovers
# 3. Papers
#     -
# 4. Data Loader
#     - https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
#     - https://www.kaggle.com/code/pinocookie/pytorch-dataset-and-dataloader
# 5. Image Processing
#     - https://www.geeksforgeeks.org/converting-an-image-to-a-torch-tensor-in-python/
#     - https://www.tutorialspoint.com/pytorch-how-to-resize-an-image-to-a-given-size
